# %% [markdown]
# ## Лаба 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Pervichnyj analiz dannyh (EDA)
df_train = pd.read_csv("smartphone_battery_drain_dataset.csv")

print("--- 1. PERVICHNYJ ANALIZ (EDA) ---")
print(f"Ishodnyj razmer dataset-a: {df_train.shape}")
print("\nPervye 5 strok:")
display(df_train.head(5))

print("\nStolbcy i tipy dannyh:")
df_train.info()

print("\nStatisticheskoe opisanie:")
display(df_train.describe())
# Out:
# --- 1. PERVICHNYJ ANALIZ (EDA) ---
# Ishodnyj razmer dataset-a: (2503, 10)
#
# Pervye 5 strok:
#   App_Running  Screen_On_Time_min  CPU_Usage_%  Battery_Temperature_C  \
# 0    Facebook           70.779244    55.550655              34.301005
# 1        PUBG           90.044282    10.506832              35.607895
# 2        Maps           75.197224    38.529769              43.312775
# 3    WhatsApp          114.762495    26.898454              33.795197
# 4    Facebook           52.214675    36.862349              41.089636
#
#    Battery_Drop_Per_Hour Network_Type  Brightness_Level_%  RAM_Usage_MB  \
# 0               6.020228           5G                  57   2941.852469
# 1              13.372379         WiFi                  10   1930.581458
# 2               3.514550           5G                  37   2169.828899
# 3               6.728475         WiFi                  33   2329.369145
# 4              19.134837           5G                  25   2175.002939
#
#   Charging_State       Usage_Mode
# 0       Charging           Gaming
# 1   Not Charging     Social Media
# 2       Charging     Social Media
# 3       Charging         Browsing
# 4       Charging  Video Streaming
# Stolbcy i tipy dannyh:
# <class 'pandas.DataFrame'>
# RangeIndex: 2503 entries, 0 to 2502
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   App_Running            2503 non-null   str
#  1   Screen_On_Time_min     2503 non-null   float64
#  2   CPU_Usage_%            2498 non-null   float64
#  3   Battery_Temperature_C  2498 non-null   float64
#  4   Battery_Drop_Per_Hour  2503 non-null   float64
#  5   Network_Type           2503 non-null   str
#  6   Brightness_Level_%     2503 non-null   int64
#  7   RAM_Usage_MB           2503 non-null   float64
#  8   Charging_State         2503 non-null   str
#  9   Usage_Mode             2503 non-null   str
# dtypes: float64(5), int64(1), str(4)
# memory usage: 195.7 KB
#
# Statisticheskoe opisanie:
#        Screen_On_Time_min  CPU_Usage_%  Battery_Temperature_C  \
# count         2503.000000  2498.000000            2498.000000
# mean            79.800996    34.480392              34.989399
# std             24.602660    15.003228               5.148660
# min              5.000000     1.000000              20.000000
# 25%             62.817364    24.231843              31.522576
# 50%             79.865066    34.245258              34.983050
# 75%             96.825940    44.617992              38.508336
# max            156.548674    83.602087              52.720325
#
#        Battery_Drop_Per_Hour  Brightness_Level_%  RAM_Usage_MB
# count            2503.000000         2503.000000   2503.000000
# mean               11.948375           51.902917   2197.331721
# std                 4.843174           27.520267    589.813489
# min                 1.000000            5.000000    500.000000
# 25%                 8.627100           27.000000   1797.226777
# 50%                11.849516           52.000000   2196.626984
# 75%                15.139305           76.000000   2596.435063
# max                27.516922           99.000000   4145.699243

# %% [markdown]
# ## 2. Очитска, обработка

# %%
df = df_train.drop_duplicates().copy()
print(f"Kolichestvo najdennyh dublikatov: {df_train.duplicated().sum()}")

print("\nPropushchennye znacheniya:")
print(df.isnull().sum())

# Statistika dlya obosnovaniya udaleniya propuskov
stats = df.groupby("Usage_Mode")[
    ["CPU_Usage_%", "Battery_Temperature_C"]
].agg(["count", "mean", "median", "std"])
print("\nStatistika po gruppam dlya analiza propuskov:")
display(stats)

df.dropna(subset=["CPU_Usage_%", "Battery_Temperature_C"], inplace=True)

numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

df_before = df.copy()
df_before["Data_State"] = "Before"

# Korrekciya znachenij
df["Battery_Temperature_C"] = df["Battery_Temperature_C"].clip(lower=0)
for pct_col in ["CPU_Usage_%", "Brightness_Level_%"]:
    df[pct_col] = df[pct_col].clip(0, 100)

df["RAM_Usage_MB"] = df["RAM_Usage_MB"].clip(lower=0)
df["Screen_On_Time_min"] = df["Screen_On_Time_min"].clip(lower=0)
df["Battery_Drop_Per_Hour"] = df["Battery_Drop_Per_Hour"].clip(lower=0)

df_after = df.copy()
df_after["Data_State"] = "After"
df_compare = pd.concat([df_before, df_after])

plt.figure(figsize=(18, 12))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data=df_compare, x="Data_State", y=col, palette="Set2")
    plt.title(f"Comparison: {col}")
    plt.xlabel("")

plt.tight_layout()
plt.show()
# Out:
# Kolichestvo najdennyh dublikatov: 3
#
# Propushchennye znacheniya:
# App_Running              0
# Screen_On_Time_min       0
# CPU_Usage_%              5
# Battery_Temperature_C    5
# Battery_Drop_Per_Hour    0
# Network_Type             0
# Brightness_Level_%       0
# RAM_Usage_MB             0
# Charging_State           0
# Usage_Mode               0
# dtype: int64
#
# Statistika po gruppam dlya analiza propuskov:
#                 CPU_Usage_%                                   \
#                       count       mean     median        std
# Usage_Mode
# Browsing                390  33.875139  32.869178  15.965944
# Gaming                  389  33.825661  33.327638  15.340177
# Music                   466  35.687992  35.329764  14.177459
# Navigation              400  36.061525  35.570936  14.405387
# Social Media            455  34.154138  34.411453  15.707002
# Video Streaming         395  33.017049  32.465203  14.238053
#
#                 Battery_Temperature_C
#                                 count       mean     median       std
# Usage_Mode
# Browsing                          390  35.326906  35.379925  5.463361
# Gaming                            391  34.560439  34.407924  5.081615
# Music                             465  35.038506  35.028428  5.309111
# Navigation                        400  34.816666  34.816822  4.955628
# Social Media                      454  35.069455  35.230717  4.910827
# Video Streaming                   395  35.128532  35.232642  5.143014
# /var/folders/cc/m264jryj4vqfwvvrwjj56tbh0000gn/T/ipykernel_21398/493501506.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_compare, x="Data_State", y=col, palette="Set2")
# /var/folders/cc/m264jryj4vqfwvvrwjj56tbh0000gn/T/ipykernel_21398/493501506.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_compare, x="Data_State", y=col, palette="Set2")
# /var/folders/cc/m264jryj4vqfwvvrwjj56tbh0000gn/T/ipykernel_21398/493501506.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_compare, x="Data_State", y=col, palette="Set2")
# /var/folders/cc/m264jryj4vqfwvvrwjj56tbh0000gn/T/ipykernel_21398/493501506.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_compare, x="Data_State", y=col, palette="Set2")
# /var/folders/cc/m264jryj4vqfwvvrwjj56tbh0000gn/T/ipykernel_21398/493501506.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_compare, x="Data_State", y=col, palette="Set2")
# /var/folders/cc/m264jryj4vqfwvvrwjj56tbh0000gn/T/ipykernel_21398/493501506.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_compare, x="Data_State", y=col, palette="Set2")

# %% [markdown]
# ## 3. Кодирование и создание новых столбцов

# %%
print("--- 3. KODIROVANIE I NOVYE PRIZNAKI ---")

df = pd.get_dummies(df, columns=["Network_Type", "Usage_Mode"], prefix=["Net", "Mode"])
df["Charging_State"] = df["Charging_State"].map({"Charging": 1, "Not Charging": 0})

freq_encoding = df["App_Running"].value_counts().to_dict()
df["App_Running_freq"] = df["App_Running"].map(freq_encoding)
df.drop("App_Running", axis=1, inplace=True)

# Sozdanie novyh stolbcov
df["Intensity"] = (df["CPU_Usage_%"] * df["RAM_Usage_MB"]) / 1000
df["Total_Battery_Drain"] = (df["Screen_On_Time_min"] / 60) * df["Battery_Drop_Per_Hour"]
temp_threshold = df["Battery_Temperature_C"].median()
df["High_Temperature"] = (df["Battery_Temperature_C"] > temp_threshold).astype(int)

print(f"Sozdany priznaki: Intensity, Total_Battery_Drain, High_Temperature")
print(f"Itogovaya razmernost: {df.shape}")
display(df.head(5))

df.to_csv("smartphone_battery_processed.csv", index=False)
print("\nFAJL SOHRANEN: LAB_2/smartphone_battery_processed.csv")
# Out:
# --- 3. KODIROVANIE I NOVYE PRIZNAKI ---
# Sozdany priznaki: Intensity, Total_Battery_Drain, High_Temperature
# Itogovaya razmernost: (2490, 20)
#    Screen_On_Time_min  CPU_Usage_%  Battery_Temperature_C  \
# 0           70.779244    55.550655              34.301005
# 1           90.044282    10.506832              35.607895
# 2           75.197224    38.529769              43.312775
# 3          114.762495    26.898454              33.795197
# 4           52.214675    36.862349              41.089636
#
#    Battery_Drop_Per_Hour  Brightness_Level_%  RAM_Usage_MB  Charging_State  \
# 0               6.020228                  57   2941.852469               1
# 1              13.372379                  10   1930.581458               0
# 2               3.514550                  37   2169.828899               1
# 3               6.728475                  33   2329.369145               1
# 4              19.134837                  25   2175.002939               1
#
#    Net_4G  Net_5G  Net_WiFi  Mode_Browsing  Mode_Gaming  Mode_Music  \
# 0   False    True     False          False         True       False
# 1   False   False      True          False        False       False
# 2   False    True     False          False        False       False
# 3   False   False      True           True        False       False
# 4   False    True     False          False        False       False
#
#    Mode_Navigation  Mode_Social Media  Mode_Video Streaming  App_Running_freq  \
# 0            False              False                 False               241
# 1            False               True                 False               238
# 2            False               True                 False               248
# 3            False              False                 False               264
# 4            False              False                  True               241
#
#     Intensity  Total_Battery_Drain  High_Temperature
# 0  163.421831             7.101787                 0
# 1   20.284296            20.068438                 1
# 2   83.603007             4.404740                 1
# 3   62.656428            12.869609                 0
# 4   80.175717            16.651988                 1
# FAJL SOHRANEN: LAB_2/smartphone_battery_processed.csv
